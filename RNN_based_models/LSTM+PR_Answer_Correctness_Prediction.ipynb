# %%
import numpy as np
import pandas as pd
import warnings
import gc
import tensorflow as tf
from tensorflow import keras

import random
from random import choice
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Concatenate, Embedding, Flatten, Activation, Dropout
from sklearn.model_selection import KFold
from tensorflow.python.client import device_lib
warnings.filterwarnings('ignore')
import random

# %%
import gc

# %% [markdown]
# ## Data Preprocessing

# %%
# load the data
import pandas as pd
dataframe = pd.read_csv("/content/drive/MyDrive/dlresearch/Practice_Log_Demographics.csv") 
dataframe.head()
# Out:
#    Unnamed: 0     term  ...  next_eligible_date  days_offset
# 0           1  WN 2018  ...                   0           23
# 1           2  WN 2018  ...                   0           33
# 2           3  WN 2018  ...                   0           57
# 3           4  WN 2018  ...                   0           12
# 4           5  WN 2018  ...                   0           54
#
# [5 rows x 760 columns]

# %%
#sort data based on timestamp
dataframe = dataframe.sort_values(by=['start_practice'])

# %%
FEATURES = ['Repeated', 'chapter_label', 'sub_chapter_label','question_name','user_id','term',
            'STDNT_SEX_CD', 
            'NonNativeEnglish',
            'White',
            'Asian',
            'WhiteOrAsian',
            'Hispanic',
            'AfricanAmerican',
            'OtherEthnicities',
            'NonWhiteOrAsian',
            'STDNT_CTZN_STAT_CD', 'international', 
            'gradingType',
            'birthYear',
            'exclClassCumGPA',
            'Freshman',
            'Junior',
            'Sophomore',
            'Senior',
            'termCreditsGPA',
            'termCreditsNoGPA',
            'athlete_1',
            'honorsPro',
            'LSA', 'programBusiness', 'programEngineering', 
            'programInformation', 'programOther',
            'HSCalculusTaken', 
            'highSchoolGPA', 
            'majorsCount', 'minorsCount',
            'PREV_TERM_CUM_GPA',
            'classGraded', 'classHonors', 
            'Pass_Fail', 
            'parentsGraduateEdu',  'minorityGroup', 
            'q',
            'available_flashcards', 
            'start_practice', 
            'end_practice',
            'days_offset']

# %%
dataframe['available_flashcards'] = dataframe["day's_available_flashcards"][:]
dataframe = dataframe.drop(["day's_available_flashcards"], axis=1)
dataframe['user_id'] = dataframe["user_id.y"][:]
dataframe = dataframe.drop(["user_id.y"], axis=1)
dataframe = dataframe.drop(["user_id.x"], axis=1)

# %%
gc.collect()
# Out:
# 61

# %%
dataframe = dataframe[FEATURES]
gc.collect()
# Out:
# 52

# %%
dataframe = dataframe.fillna(0)
#transform q value so that if it is >= 4 it would be
#considered as 1 (correct) and if <4 0(incorrect)
dataframe['answer_correct'] = np.where(dataframe['q']>=4, 1, 0)
dataframe['answer_correct'].mean()
# Out:
# 0.5326395552433993

# %%
#label encode term, chapter_label, question_name, sub_chapter_label columns
dataframe['term'] = dataframe['term'].astype('category')
dataframe['user_id'] = dataframe['user_id'].astype(int)
dataframe['user_id'] = dataframe['user_id'].astype(str)
dataframe['user_id'] = dataframe['term'].str.cat(dataframe['user_id'], sep=':')
dataframe['user_id'] = dataframe['user_id'].astype('category')
dataframe['chapter_label'] = dataframe['chapter_label'].astype('category')
dataframe['sub_chapter_label'] = dataframe['sub_chapter_label'].astype('category')
dataframe['question_name'] = dataframe['question_name'].astype('category')

# %%
#calculate time_lag and prev_time_elapsed
dataframe['prev_time_elapsed'] = None
dataframe['time_lag'] = None
dataframe['time_lag'] = dataframe['time_lag'].astype(np.float)
dataframe['prev_time_elapsed'] = dataframe['prev_time_elapsed'].astype(np.float)
dataframe.start_practice = pd.to_datetime(dataframe.start_practice, format='%Y-%m-%d %H:%M:%S')
dataframe.end_practice = pd.to_datetime(dataframe.end_practice, format='%Y-%m-%d %H:%M:%S')

# %%
from tqdm import tqdm
for user in tqdm(dataframe['user_id'].unique()):
    tmp_user = dataframe[dataframe['user_id']==user]
    tmp_time_elapsed = tmp_user.end_practice.apply(lambda a: a.timestamp()) - tmp_user.start_practice.apply(lambda a: a.timestamp())
    #shifting time elapsed by one
    #so that time_elapsed row for each question
    #would refer to the time that user took to answer
    #previous question
    tmp_time_elapsed = np.insert(np.array(tmp_time_elapsed[:-1]), 0, -1., axis=0)
    indices = tmp_user.index
    start_row = indices[0]
    dataframe['time_lag'].iloc[start_row] = -1
    time_substrahend = tmp_user.start_practice.iloc[:-1]
    time_substrahend = time_substrahend.apply(lambda a: a.timestamp())
    time_substrahend = np.array(time_substrahend)

    time_minuend = tmp_user.start_practice.iloc[1:]
    time_minuend = time_minuend.apply(lambda a: a.timestamp())
    time_minuend = np.array(time_minuend)
    
    dataframe['prev_time_elapsed'].iloc[indices] = tmp_time_elapsed
    dataframe['time_lag'].iloc[indices[1:]] = time_minuend - time_substrahend
# Out:
# 100%|██████████| 887/887 [00:11<00:00, 78.90it/s]

# %%
# remove students who are taking the course for a second time
dataframe  = dataframe[dataframe['Repeated'] == ' ']
gc.collect()
# Out:
# 50

# %%
#drop column end_practice
dataframe.drop(columns=['end_practice'], inplace=True)

# %%
dataframe['term_value'] = [int(ele[3:]) for ele in dataframe['term']]
dataframe['age'] = dataframe['term_value'] - dataframe['birthYear']

# %%
# calculate the age feature
dataframe['term_value'] = [int(ele[3:]) for ele in dataframe['term']]
dataframe['age'] = dataframe['term_value'] - dataframe['birthYear']

# %%
# convert minors_count to int value
new_minors_count = []
for i in dataframe['minorsCount']:
  if i == 0 or i == '0':
    new_minors_count.append(0)
  elif i == '1 Minor':
    new_minors_count.append(1)
  else:
    new_minors_count.append(2)

dataframe['minorsCount'] = new_minors_count

# %%
print("we have ", dataframe['user_id'].nunique()," users in total.")
# Out:
# we have  881  users in total.

# %%
for category in ['term','chapter_label', 'sub_chapter_label', 'question_name']:
  dataframe[category] =  dataframe[category].cat.codes

# %%
NUMERIC_FEATURE =  ['age',
            'exclClassCumGPA',
            'termCreditsGPA',
            'termCreditsNoGPA',
            'highSchoolGPA', 
            'majorsCount', 'minorsCount',
            'PREV_TERM_CUM_GPA',
            'available_flashcards', 
            'days_offset', 
            'prev_time_elapsed',
             'time_lag']

for f in NUMERIC_FEATURE:
  m = dataframe[f].mean()
  std = dataframe[f].std()
  dataframe[f] = (dataframe[f] - m)/std

# %%
FEATURE_TRANS =  ['answer_correct', 'chapter_label', 'sub_chapter_label','question_name','user_id','term',
                  'STDNT_SEX_CD', 
                    'White','Asian','NonWhiteOrAsian',
            'STDNT_CTZN_STAT_CD', 'international', 
            'age',
            'exclClassCumGPA',
           'Freshman',
            'Junior',
            'Sophomore',
            'Senior',
            'termCreditsGPA',
            'termCreditsNoGPA',
            'athlete_1',
            'honorsPro',
            'LSA', 'programBusiness', 'programEngineering', 
            'programInformation', 'programOther',
            'HSCalculusTaken', 
            'highSchoolGPA', 

            'majorsCount', 'minorsCount',

            'PREV_TERM_CUM_GPA',
            'classGraded', 'classHonors', 
            'Pass_Fail', 
            'parentsGraduateEdu',  'minorityGroup', 
            'available_flashcards', 
            'days_offset', 'prev_time_elapsed',
             'time_lag']
grouped_data = dataframe[FEATURE_TRANS].groupby(['user_id']).apply(lambda r: (
                r['answer_correct'],
                r['term'],
                r['chapter_label'],
                r['sub_chapter_label'],
                r['question_name'],
                np.array([r['STDNT_SEX_CD'],r['STDNT_CTZN_STAT_CD'], r['international'], 
                  r['White'],r['Asian'],r['NonWhiteOrAsian'],
                 r['age'],r['exclClassCumGPA'],
                r['Freshman'], r['Junior'], r['Sophomore'], r['Senior'],
                r['termCreditsGPA'], r['termCreditsNoGPA'],
                r['athlete_1'], r['honorsPro'],
                r['LSA'], r['programBusiness'], r['programEngineering'], 
                r['programInformation'], r['programOther'],
                r['HSCalculusTaken'],  r['highSchoolGPA'], 
                r['majorsCount'], r['minorsCount'],
                r['PREV_TERM_CUM_GPA'], 
                r['parentsGraduateEdu'], r['minorityGroup'],
                r['available_flashcards'],
                r['days_offset'],
                r['prev_time_elapsed'],
                r['time_lag']
              ]).transpose()
                ))

# %%
gc.collect()
# Out:
# 129

# %%
# remove students who don't have make any interactions with the tool
toRemove = []
for index in grouped_data.index:
  if len(grouped_data[index][0]) <= 10:
    toRemove.append(index)
grouped_data = grouped_data.drop(index=toRemove)

# %%
grouped_data = grouped_data.drop(index=toRemove)

# %%
num_interact = 0
count  = 0
max_num_interact = 0
for g in grouped_data:
  if len(g[0])<10:
    print(len(g[0]))
  if len(g[0]) > max_num_interact:
    max_num_interact = len(g[0])
  num_interact += len(g[0])
  count += 1
print(num_interact/count)
print(max_num_interact)
# Out:
# 569.2372304199773
# 1348

# %%
#SETTINGS -> can be modified at any time
MAXLENGTH = 500
EMBEDDING_DIM = 128
DENSE_NEURON = 16
LSTM_NEURON = 32

# %%
FEATURES_SIZE = 39
CHAPTER_SIZE = 38
SUB_CHAPTER_SIZE = 222
QUESTION_SIZE = 1065

# %%
#create dataset class
#to prepare it for train, valid, and test sets
from torch.utils.data import Dataset, DataLoader
class SPACE_DATASET(Dataset):
    def __init__(self, data, maxlength = 100):
        super(SPACE_DATASET, self).__init__()
        self.maxlength = maxlength
        self.data = data
        self.users = list()
        for user in data.index:
            self.users.append(user)

    def __len__(self):
        return len(self.users)
    
    def __getitem__(self, ix):
        user = self.users[ix]
        user = user
        target, term, ch_label, sub_ch_label, ques_name, features = self.data[user]
        
        #0s should be used as padding values
        ori_target = target.values 
        term = term.values
        ch_label = ch_label.values + 1
        sub_ch_label = sub_ch_label.values +1
        ques_name = ques_name.values + 1
        
        n = len(ch_label)

        # one hot for term
        term_encode = [0]*6
        term_encode[term[0]] = 1
        shifted_target= []

        
        # get  user interaction informations in the previous MAXLEN interactions
        if n > self.maxlength:
          ch_label = ch_label[-self.maxlength:]
          sub_ch_label = sub_ch_label[-self.maxlength:]
          ques_name = ques_name[-self.maxlength:]
          features = features[-self.maxlength:]
          target = ori_target[-self.maxlength:]
          shifted_target = ori_target[ (-self.maxlength - 1) :-1]
        else:
          ch_label = [0]*(self.maxlength - n)+list(ch_label[:])
          sub_ch_label = [0]*(self.maxlength - n)+list(sub_ch_label[:])
          ques_name = [0]*(self.maxlength - n)+list(ques_name[:])
          features = [[0]*len(features[0])]*(self.maxlength  - n)+list(features[:])
          target = [-1]*(self.maxlength - n) + list(ori_target[:])
          shifted_target = [-1]*(self.maxlength + 1 - n) + list(ori_target[:-1])

        new_features = []
        count = 0
        for f in features:
          temp = list(f)
          temp.extend(term_encode)
          temp.append(shifted_target[count]) #uncomment this line for include previous response feature
          new_features.append(temp)
          
          count += 1
        
        features = new_features
        
        return ch_label,sub_ch_label,ques_name,features,target

# %% [markdown]
# ## KFOLD - LSTM

# %%
# 5 fold cross validation with GRU-based model
import torch
X = np.array(grouped_data.keys())
kfold = KFold(n_splits=5, shuffle=True)
train_losses = list()
train_aucs = list()
val_losses = list()
val_aucs = list()
train_eval= list()
test_eval = list()
for train, test in kfold.split(X):
    users_train, users_test =  X[train], X[test]
    n = len(users_test)//2
    users_test, users_val = users_test[:n], users_test[n: ]
    train_data_space = SPACE_DATASET(grouped_data[users_train], MAXLENGTH)
    val_data_space = SPACE_DATASET(grouped_data[users_val], MAXLENGTH)
    test_data_space = SPACE_DATASET(grouped_data[users_test], MAXLENGTH)
    #construct training input
    train_chapter=[]
    train_sub_chapter=[]
    train_question = []
    train_features=[]
    train_labels=[]
    for i in range(len(users_train)):
        user = train_data_space.__getitem__(i)
        train_chapter.append(user[0])
        train_sub_chapter.append(user[1]) 
        train_question.append(user[2])
        train_features.append(user[3])
        train_labels.append(user[4])
    train_chapter = np.array(train_chapter)
    train_sub_chapter = np.array(train_sub_chapter)
    train_question = np.array(train_question)
    train_features = np.array(train_features)
    train_labels= np.array(train_labels)[..., np.newaxis]

    #construct validation input
    val_chapter=[]
    val_sub_chapter=[]
    val_question = []
    val_features=[]
    val_labels=[]
    for i in range(len(users_val)):
        user = val_data_space.__getitem__(i)
        val_chapter.append(user[0])
        val_sub_chapter.append(user[1]) 
        val_question.append(user[2])
        val_features.append(user[3])
        val_labels.append(user[4])
    val_chapter = np.array(val_chapter)
    val_sub_chapter = np.array(val_sub_chapter)
    val_features = np.array(val_features)
    val_question = np.array(val_question)
    val_labels= np.array(val_labels)[..., np.newaxis]

    # construct test input
    test_chapter=[]
    test_sub_chapter=[]
    test_features=[]
    test_question=[]
    test_labels=[]
    for i in range(len(users_test)):
        user = test_data_space.__getitem__(i)
        test_chapter.append(user[0])
        test_sub_chapter.append(user[1]) 
        test_question.append(user[2])
        test_features.append(user[3])
        test_labels.append(user[4])
    test_chapter = np.array(test_chapter)
    test_sub_chapter = np.array(test_sub_chapter)
    test_features = np.array(test_features)
    test_question = np.array(test_question)
    test_labels= np.array(test_labels)[..., np.newaxis]

    # define loss function and evaluation metrics
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    acc = tf.keras.metrics.Accuracy()
    auc = tf.keras.metrics.AUC()

    def masked_bce(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return bce(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_acc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      flat_pred = (flat_pred >= 0.5)
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return acc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    def masked_auc(y_true, y_pred):
      flat_pred = y_pred
      flat_ground_truth = y_true
      label_mask = tf.math.not_equal(flat_ground_truth, -1)
      return auc(flat_ground_truth, flat_pred, sample_weight=label_mask)

    # input layer
    input_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_sub_chap = tf.keras.Input(shape=(MAXLENGTH))
    input_ques =  tf.keras.Input(shape=(MAXLENGTH))
    input_features = tf.keras.Input(shape=(MAXLENGTH, FEATURES_SIZE))

    # embedding layer for categorical features
    embedding_chap = Embedding(input_dim = CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_chap)
    embedding_sub_chap = Embedding(input_dim = SUB_CHAPTER_SIZE, output_dim = EMBEDDING_DIM)(input_sub_chap) 
    embedding_ques = Embedding(input_dim = QUESTION_SIZE, output_dim = EMBEDDING_DIM)(input_ques)       

    # dense layer for numeric features
    dense_features = Dense(EMBEDDING_DIM,input_shape = (None, MAXLENGTH))(input_features)



    # lstm layers
    lstm_chap = LSTM(LSTM_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_chap)
    lstm_sub_chap = LSTM(LSTM_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_sub_chap)
    lstm_ques = LSTM(LSTM_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(embedding_ques)
    lstm_features = LSTM(LSTM_NEURON, input_shape = (None, EMBEDDING_DIM),return_sequences = True)(dense_features)

    lstm_output = tf.concat([lstm_chap, lstm_sub_chap, lstm_ques,lstm_features], axis = 2)

    dense1 = Dense(256, input_shape = (None, 4*EMBEDDING_DIM), activation='relu')(lstm_output)
    dropout1 = Dropout(0.1)(dense1)
    dense2 = Dense(64, input_shape = (None, 256), activation='relu')(dropout1)
    dropout2 = Dropout(0.1)(dense2)
    pred = Dense(1, input_shape = (None, 64), activation='sigmoid')(dropout2)

    model = tf.keras.Model(
        inputs=[input_chap, input_sub_chap,input_ques, input_features],
        outputs=pred,
        name='lstm_model'
    )

    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    opt_adam = Adam(learning_rate = 0.005)
    model.compile(
        optimizer=opt_adam,
        loss= masked_bce,
        metrics = [masked_acc, masked_auc]
    )

    history = model.fit(
      [train_chapter, train_sub_chapter, train_question, train_features],
      train_labels,
      batch_size = 64,
      epochs = 100,
      validation_data=([val_chapter, val_sub_chapter, val_question, val_features], val_labels),
      callbacks=[callback]
    )
    val_losses.append(list(history.history['val_loss']))
    train_losses.append(list(history.history['loss']))
    val_aucs.append(list(history.history['val_masked_auc']))
    train_aucs.append(list(history.history['masked_auc']))
    train_score = model.evaluate([train_chapter, train_sub_chapter, train_question, train_features], train_labels)
    train_eval.append(train_score)
    test_score = model.evaluate([test_chapter, test_sub_chapter, test_question, test_features], test_labels)
    test_eval.append(test_score)
    print("Test: ", test_score)
    def reset_weights(model):
      for layer in model.layers: 
        if isinstance(layer, tf.keras.Model):
          reset_weights(layer)
          continue
        for k, initializer in layer.__dict__.items():
          if "initializer" not in k:
            continue
          # find the corresponding variable
          var = getattr(layer, k.replace("_initializer", ""))
          var.assign(initializer(var.shape, var.dtype))
    reset_weights(model)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 39s 273ms/step - loss: 0.6145 - masked_acc: 0.5611 - masked_auc: 0.5573 - val_loss: 0.5284 - val_masked_acc: 0.6279 - val_masked_auc: 0.6743
# Epoch 2/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.5283 - masked_acc: 0.6456 - masked_auc: 0.6980 - val_loss: 0.4668 - val_masked_acc: 0.6771 - val_masked_auc: 0.7402
# Epoch 3/100
# 11/11 [==============================] - 1s 102ms/step - loss: 0.4679 - masked_acc: 0.6877 - masked_auc: 0.7534 - val_loss: 0.4365 - val_masked_acc: 0.7046 - val_masked_auc: 0.7746
# Epoch 4/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.4478 - masked_acc: 0.7103 - masked_auc: 0.7816 - val_loss: 0.4332 - val_masked_acc: 0.7205 - val_masked_auc: 0.7935
# Epoch 5/100
# 11/11 [==============================] - 1s 104ms/step - loss: 0.4413 - masked_acc: 0.7244 - masked_auc: 0.7977 - val_loss: 0.4295 - val_masked_acc: 0.7307 - val_masked_auc: 0.8049
# Epoch 6/100
# 11/11 [==============================] - 1s 105ms/step - loss: 0.4381 - masked_acc: 0.7331 - masked_auc: 0.8077 - val_loss: 0.4273 - val_masked_acc: 0.7378 - val_masked_auc: 0.8129
# Epoch 7/100
# 11/11 [==============================] - 1s 106ms/step - loss: 0.4294 - masked_acc: 0.7398 - masked_auc: 0.8150 - val_loss: 0.4254 - val_masked_acc: 0.7433 - val_masked_auc: 0.8189
# Epoch 8/100
# 11/11 [==============================] - 1s 105ms/step - loss: 0.4326 - masked_acc: 0.7449 - masked_auc: 0.8205 - val_loss: 0.4281 - val_masked_acc: 0.7476 - val_masked_auc: 0.8235
# Epoch 9/100
# 11/11 [==============================] - 1s 106ms/step - loss: 0.4250 - masked_acc: 0.7488 - masked_auc: 0.8246 - val_loss: 0.4231 - val_masked_acc: 0.7511 - val_masked_auc: 0.8273
# Epoch 10/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.4253 - masked_acc: 0.7520 - masked_auc: 0.8283 - val_loss: 0.4243 - val_masked_acc: 0.7541 - val_masked_auc: 0.8305
# Epoch 11/100
# 11/11 [==============================] - 1s 102ms/step - loss: 0.4193 - masked_acc: 0.7550 - masked_auc: 0.8315 - val_loss: 0.4224 - val_masked_acc: 0.7567 - val_masked_auc: 0.8334
# Epoch 12/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.4208 - masked_acc: 0.7574 - masked_auc: 0.8342 - val_loss: 0.4258 - val_masked_acc: 0.7589 - val_masked_auc: 0.8358
# Epoch 13/100
# 11/11 [==============================] - 1s 106ms/step - loss: 0.4118 - masked_acc: 0.7596 - masked_auc: 0.8366 - val_loss: 0.4234 - val_masked_acc: 0.7609 - val_masked_auc: 0.8380
# Epoch 14/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.4151 - masked_acc: 0.7615 - masked_auc: 0.8387 - val_loss: 0.4261 - val_masked_acc: 0.7628 - val_masked_auc: 0.8400
# Epoch 15/100
# 11/11 [==============================] - 1s 105ms/step - loss: 0.4112 - masked_acc: 0.7634 - masked_auc: 0.8407 - val_loss: 0.4272 - val_masked_acc: 0.7644 - val_masked_auc: 0.8419
# Epoch 16/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.4103 - masked_acc: 0.7649 - masked_auc: 0.8424 - val_loss: 0.4308 - val_masked_acc: 0.7660 - val_masked_auc: 0.8436
# Epoch 17/100
# 11/11 [==============================] - 1s 102ms/step - loss: 0.4059 - masked_acc: 0.7664 - masked_auc: 0.8441 - val_loss: 0.4291 - val_masked_acc: 0.7674 - val_masked_auc: 0.8452
# Epoch 18/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.3981 - masked_acc: 0.7678 - masked_auc: 0.8457 - val_loss: 0.4302 - val_masked_acc: 0.7687 - val_masked_auc: 0.8466
# Epoch 19/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.4000 - masked_acc: 0.7691 - masked_auc: 0.8471 - val_loss: 0.4351 - val_masked_acc: 0.7699 - val_masked_auc: 0.8480
# Epoch 20/100
# 11/11 [==============================] - 1s 103ms/step - loss: 0.3987 - masked_acc: 0.7703 - masked_auc: 0.8485 - val_loss: 0.4378 - val_masked_acc: 0.7711 - val_masked_auc: 0.8494
# Epoch 21/100
# 11/11 [==============================] - 1s 104ms/step - loss: 0.3992 - masked_acc: 0.7715 - masked_auc: 0.8498 - val_loss: 0.4403 - val_masked_acc: 0.7722 - val_masked_auc: 0.8506
# 22/22 [==============================] - 2s 39ms/step - loss: 0.3927 - masked_acc: 0.7727 - masked_auc: 0.8513
# 3/3 [==============================] - 0s 36ms/step - loss: 0.4769 - masked_acc: 0.7732 - masked_auc: 0.8518
# Test:  [0.47685354948043823, 0.7731575965881348, 0.8517809510231018]
# Epoch 1/100
# 12/12 [==============================] - 9s 270ms/step - loss: 0.6215 - masked_acc: 0.5263 - masked_auc: 0.5447 - val_loss: 0.5366 - val_masked_acc: 0.6130 - val_masked_auc: 0.6629
# Epoch 2/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.5312 - masked_acc: 0.6337 - masked_auc: 0.6900 - val_loss: 0.4662 - val_masked_acc: 0.6669 - val_masked_auc: 0.7323
# Epoch 3/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4799 - masked_acc: 0.6784 - masked_auc: 0.7463 - val_loss: 0.4574 - val_masked_acc: 0.6945 - val_masked_auc: 0.7652
# Epoch 4/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4647 - masked_acc: 0.7005 - masked_auc: 0.7721 - val_loss: 0.4397 - val_masked_acc: 0.7107 - val_masked_auc: 0.7838
# Epoch 5/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4578 - masked_acc: 0.7145 - masked_auc: 0.7880 - val_loss: 0.4563 - val_masked_acc: 0.7212 - val_masked_auc: 0.7954
# Epoch 6/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4584 - masked_acc: 0.7238 - masked_auc: 0.7982 - val_loss: 0.4316 - val_masked_acc: 0.7285 - val_masked_auc: 0.8032
# Epoch 7/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4489 - masked_acc: 0.7305 - masked_auc: 0.8053 - val_loss: 0.4331 - val_masked_acc: 0.7342 - val_masked_auc: 0.8093
# Epoch 8/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4555 - masked_acc: 0.7357 - masked_auc: 0.8106 - val_loss: 0.4303 - val_masked_acc: 0.7386 - val_masked_auc: 0.8135
# Epoch 9/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4381 - masked_acc: 0.7401 - masked_auc: 0.8149 - val_loss: 0.4290 - val_masked_acc: 0.7425 - val_masked_auc: 0.8176
# Epoch 10/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4470 - masked_acc: 0.7435 - masked_auc: 0.8186 - val_loss: 0.4298 - val_masked_acc: 0.7455 - val_masked_auc: 0.8207
# Epoch 11/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4345 - masked_acc: 0.7464 - masked_auc: 0.8216 - val_loss: 0.4263 - val_masked_acc: 0.7479 - val_masked_auc: 0.8233
# Epoch 12/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4357 - masked_acc: 0.7487 - masked_auc: 0.8241 - val_loss: 0.4270 - val_masked_acc: 0.7501 - val_masked_auc: 0.8257
# Epoch 13/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4386 - masked_acc: 0.7507 - masked_auc: 0.8263 - val_loss: 0.4335 - val_masked_acc: 0.7519 - val_masked_auc: 0.8276
# Epoch 14/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4374 - masked_acc: 0.7525 - masked_auc: 0.8282 - val_loss: 0.4309 - val_masked_acc: 0.7536 - val_masked_auc: 0.8295
# Epoch 15/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4305 - masked_acc: 0.7542 - masked_auc: 0.8301 - val_loss: 0.4290 - val_masked_acc: 0.7553 - val_masked_auc: 0.8312
# Epoch 16/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4246 - masked_acc: 0.7558 - masked_auc: 0.8318 - val_loss: 0.4323 - val_masked_acc: 0.7567 - val_masked_auc: 0.8328
# Epoch 17/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4274 - masked_acc: 0.7572 - masked_auc: 0.8333 - val_loss: 0.4296 - val_masked_acc: 0.7580 - val_masked_auc: 0.8342
# Epoch 18/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4326 - masked_acc: 0.7583 - masked_auc: 0.8345 - val_loss: 0.4265 - val_masked_acc: 0.7591 - val_masked_auc: 0.8354
# Epoch 19/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4318 - masked_acc: 0.7594 - masked_auc: 0.8357 - val_loss: 0.4256 - val_masked_acc: 0.7601 - val_masked_auc: 0.8365
# Epoch 20/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4258 - masked_acc: 0.7604 - masked_auc: 0.8368 - val_loss: 0.4240 - val_masked_acc: 0.7611 - val_masked_auc: 0.8376
# Epoch 21/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4246 - masked_acc: 0.7614 - masked_auc: 0.8379 - val_loss: 0.4244 - val_masked_acc: 0.7621 - val_masked_auc: 0.8386
# Epoch 22/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4252 - masked_acc: 0.7624 - masked_auc: 0.8390 - val_loss: 0.4239 - val_masked_acc: 0.7631 - val_masked_auc: 0.8397
# Epoch 23/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4108 - masked_acc: 0.7634 - masked_auc: 0.8401 - val_loss: 0.4290 - val_masked_acc: 0.7640 - val_masked_auc: 0.8408
# Epoch 24/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4179 - masked_acc: 0.7643 - masked_auc: 0.8411 - val_loss: 0.4249 - val_masked_acc: 0.7648 - val_masked_auc: 0.8417
# Epoch 25/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4079 - masked_acc: 0.7652 - masked_auc: 0.8421 - val_loss: 0.4252 - val_masked_acc: 0.7657 - val_masked_auc: 0.8426
# Epoch 26/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4159 - masked_acc: 0.7660 - masked_auc: 0.8429 - val_loss: 0.4245 - val_masked_acc: 0.7665 - val_masked_auc: 0.8435
# Epoch 27/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4119 - masked_acc: 0.7667 - masked_auc: 0.8438 - val_loss: 0.4304 - val_masked_acc: 0.7673 - val_masked_auc: 0.8444
# Epoch 28/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4133 - masked_acc: 0.7675 - masked_auc: 0.8447 - val_loss: 0.4391 - val_masked_acc: 0.7679 - val_masked_auc: 0.8452
# Epoch 29/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4175 - masked_acc: 0.7682 - masked_auc: 0.8454 - val_loss: 0.4474 - val_masked_acc: 0.7685 - val_masked_auc: 0.8458
# Epoch 30/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4222 - masked_acc: 0.7687 - masked_auc: 0.8460 - val_loss: 0.4327 - val_masked_acc: 0.7691 - val_masked_auc: 0.8464
# Epoch 31/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4132 - masked_acc: 0.7693 - masked_auc: 0.8466 - val_loss: 0.4318 - val_masked_acc: 0.7696 - val_masked_auc: 0.8470
# Epoch 32/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4070 - masked_acc: 0.7698 - masked_auc: 0.8472 - val_loss: 0.4345 - val_masked_acc: 0.7702 - val_masked_auc: 0.8476
# 23/23 [==============================] - 1s 40ms/step - loss: 0.4051 - masked_acc: 0.7705 - masked_auc: 0.8479
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4609 - masked_acc: 0.7708 - masked_auc: 0.8483
# Test:  [0.46085309982299805, 0.7707583904266357, 0.8482603430747986]
# Epoch 1/100
# 12/12 [==============================] - 8s 246ms/step - loss: 0.6239 - masked_acc: 0.5545 - masked_auc: 0.5504 - val_loss: 0.5389 - val_masked_acc: 0.6122 - val_masked_auc: 0.6506
# Epoch 2/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.5341 - masked_acc: 0.6320 - masked_auc: 0.6798 - val_loss: 0.5054 - val_masked_acc: 0.6604 - val_masked_auc: 0.7190
# Epoch 3/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.5078 - masked_acc: 0.6695 - masked_auc: 0.7305 - val_loss: 0.4795 - val_masked_acc: 0.6836 - val_masked_auc: 0.7475
# Epoch 4/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4774 - masked_acc: 0.6898 - masked_auc: 0.7554 - val_loss: 0.4483 - val_masked_acc: 0.7005 - val_masked_auc: 0.7683
# Epoch 5/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4626 - masked_acc: 0.7049 - masked_auc: 0.7734 - val_loss: 0.4386 - val_masked_acc: 0.7122 - val_masked_auc: 0.7821
# Epoch 6/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4534 - masked_acc: 0.7153 - masked_auc: 0.7859 - val_loss: 0.4275 - val_masked_acc: 0.7210 - val_masked_auc: 0.7925
# Epoch 7/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4480 - masked_acc: 0.7235 - masked_auc: 0.7954 - val_loss: 0.4267 - val_masked_acc: 0.7278 - val_masked_auc: 0.8003
# Epoch 8/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4455 - masked_acc: 0.7297 - masked_auc: 0.8022 - val_loss: 0.4263 - val_masked_acc: 0.7329 - val_masked_auc: 0.8059
# Epoch 9/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4454 - masked_acc: 0.7342 - masked_auc: 0.8074 - val_loss: 0.4213 - val_masked_acc: 0.7370 - val_masked_auc: 0.8104
# Epoch 10/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4504 - masked_acc: 0.7381 - masked_auc: 0.8115 - val_loss: 0.4204 - val_masked_acc: 0.7401 - val_masked_auc: 0.8137
# Epoch 11/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.4417 - masked_acc: 0.7412 - masked_auc: 0.8149 - val_loss: 0.4180 - val_masked_acc: 0.7431 - val_masked_auc: 0.8170
# Epoch 12/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4391 - masked_acc: 0.7440 - masked_auc: 0.8180 - val_loss: 0.4173 - val_masked_acc: 0.7456 - val_masked_auc: 0.8198
# Epoch 13/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4325 - masked_acc: 0.7464 - masked_auc: 0.8207 - val_loss: 0.4217 - val_masked_acc: 0.7476 - val_masked_auc: 0.8221
# Epoch 14/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4412 - masked_acc: 0.7482 - masked_auc: 0.8227 - val_loss: 0.4257 - val_masked_acc: 0.7492 - val_masked_auc: 0.8238
# Epoch 15/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.4460 - masked_acc: 0.7496 - masked_auc: 0.8242 - val_loss: 0.4229 - val_masked_acc: 0.7505 - val_masked_auc: 0.8251
# Epoch 16/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4402 - masked_acc: 0.7509 - masked_auc: 0.8256 - val_loss: 0.4176 - val_masked_acc: 0.7519 - val_masked_auc: 0.8266
# Epoch 17/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4291 - masked_acc: 0.7524 - masked_auc: 0.8272 - val_loss: 0.4159 - val_masked_acc: 0.7533 - val_masked_auc: 0.8282
# Epoch 18/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4335 - masked_acc: 0.7538 - masked_auc: 0.8288 - val_loss: 0.4145 - val_masked_acc: 0.7547 - val_masked_auc: 0.8298
# Epoch 19/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.4254 - masked_acc: 0.7551 - masked_auc: 0.8303 - val_loss: 0.4190 - val_masked_acc: 0.7559 - val_masked_auc: 0.8313
# Epoch 20/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4259 - masked_acc: 0.7564 - masked_auc: 0.8317 - val_loss: 0.4200 - val_masked_acc: 0.7571 - val_masked_auc: 0.8326
# Epoch 21/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4280 - masked_acc: 0.7574 - masked_auc: 0.8330 - val_loss: 0.4186 - val_masked_acc: 0.7581 - val_masked_auc: 0.8338
# Epoch 22/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4252 - masked_acc: 0.7585 - masked_auc: 0.8342 - val_loss: 0.4174 - val_masked_acc: 0.7591 - val_masked_auc: 0.8349
# Epoch 23/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4198 - masked_acc: 0.7595 - masked_auc: 0.8353 - val_loss: 0.4178 - val_masked_acc: 0.7601 - val_masked_auc: 0.8360
# Epoch 24/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4210 - masked_acc: 0.7604 - masked_auc: 0.8364 - val_loss: 0.4171 - val_masked_acc: 0.7610 - val_masked_auc: 0.8370
# Epoch 25/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4241 - masked_acc: 0.7612 - masked_auc: 0.8373 - val_loss: 0.4170 - val_masked_acc: 0.7617 - val_masked_auc: 0.8378
# Epoch 26/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4256 - masked_acc: 0.7619 - masked_auc: 0.8381 - val_loss: 0.4168 - val_masked_acc: 0.7624 - val_masked_auc: 0.8387
# Epoch 27/100
# 12/12 [==============================] - 1s 107ms/step - loss: 0.4174 - masked_acc: 0.7627 - masked_auc: 0.8390 - val_loss: 0.4299 - val_masked_acc: 0.7631 - val_masked_auc: 0.8395
# Epoch 28/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4265 - masked_acc: 0.7633 - masked_auc: 0.8397 - val_loss: 0.4319 - val_masked_acc: 0.7637 - val_masked_auc: 0.8402
# 23/23 [==============================] - 1s 40ms/step - loss: 0.4221 - masked_acc: 0.7640 - masked_auc: 0.8405
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4703 - masked_acc: 0.7643 - masked_auc: 0.8408
# Test:  [0.4702763557434082, 0.764338493347168, 0.8407702445983887]
# Epoch 1/100
# 12/12 [==============================] - 8s 245ms/step - loss: 0.6280 - masked_acc: 0.5267 - masked_auc: 0.5451 - val_loss: 0.5709 - val_masked_acc: 0.6052 - val_masked_auc: 0.6477
# Epoch 2/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.5421 - masked_acc: 0.6232 - masked_auc: 0.6728 - val_loss: 0.5106 - val_masked_acc: 0.6540 - val_masked_auc: 0.7149
# Epoch 3/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4961 - masked_acc: 0.6644 - masked_auc: 0.7283 - val_loss: 0.4784 - val_masked_acc: 0.6826 - val_masked_auc: 0.7506
# Epoch 4/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.4757 - masked_acc: 0.6892 - masked_auc: 0.7582 - val_loss: 0.4569 - val_masked_acc: 0.7007 - val_masked_auc: 0.7716
# Epoch 5/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4560 - masked_acc: 0.7051 - masked_auc: 0.7767 - val_loss: 0.4557 - val_masked_acc: 0.7128 - val_masked_auc: 0.7855
# Epoch 6/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4513 - masked_acc: 0.7160 - masked_auc: 0.7891 - val_loss: 0.4432 - val_masked_acc: 0.7215 - val_masked_auc: 0.7953
# Epoch 7/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4481 - masked_acc: 0.7240 - masked_auc: 0.7979 - val_loss: 0.4533 - val_masked_acc: 0.7284 - val_masked_auc: 0.8027
# Epoch 8/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.4529 - masked_acc: 0.7300 - masked_auc: 0.8042 - val_loss: 0.4588 - val_masked_acc: 0.7326 - val_masked_auc: 0.8067
# Epoch 9/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4615 - masked_acc: 0.7336 - masked_auc: 0.8077 - val_loss: 0.4489 - val_masked_acc: 0.7357 - val_masked_auc: 0.8098
# Epoch 10/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4485 - masked_acc: 0.7368 - masked_auc: 0.8109 - val_loss: 0.4409 - val_masked_acc: 0.7386 - val_masked_auc: 0.8127
# Epoch 11/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4440 - masked_acc: 0.7396 - masked_auc: 0.8138 - val_loss: 0.4381 - val_masked_acc: 0.7415 - val_masked_auc: 0.8159
# Epoch 12/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4388 - masked_acc: 0.7424 - masked_auc: 0.8168 - val_loss: 0.4407 - val_masked_acc: 0.7441 - val_masked_auc: 0.8186
# Epoch 13/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4360 - masked_acc: 0.7449 - masked_auc: 0.8194 - val_loss: 0.4385 - val_masked_acc: 0.7462 - val_masked_auc: 0.8209
# Epoch 14/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4350 - masked_acc: 0.7469 - masked_auc: 0.8216 - val_loss: 0.4387 - val_masked_acc: 0.7482 - val_masked_auc: 0.8230
# Epoch 15/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.4373 - masked_acc: 0.7488 - masked_auc: 0.8236 - val_loss: 0.4334 - val_masked_acc: 0.7501 - val_masked_auc: 0.8251
# Epoch 16/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4340 - masked_acc: 0.7507 - masked_auc: 0.8257 - val_loss: 0.4322 - val_masked_acc: 0.7519 - val_masked_auc: 0.8270
# Epoch 17/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4297 - masked_acc: 0.7525 - masked_auc: 0.8277 - val_loss: 0.4323 - val_masked_acc: 0.7534 - val_masked_auc: 0.8287
# Epoch 18/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4260 - masked_acc: 0.7539 - masked_auc: 0.8293 - val_loss: 0.4337 - val_masked_acc: 0.7549 - val_masked_auc: 0.8303
# Epoch 19/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4227 - masked_acc: 0.7553 - masked_auc: 0.8308 - val_loss: 0.4355 - val_masked_acc: 0.7561 - val_masked_auc: 0.8317
# Epoch 20/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4265 - masked_acc: 0.7565 - masked_auc: 0.8321 - val_loss: 0.4339 - val_masked_acc: 0.7574 - val_masked_auc: 0.8330
# Epoch 21/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.4254 - masked_acc: 0.7578 - masked_auc: 0.8334 - val_loss: 0.4322 - val_masked_acc: 0.7586 - val_masked_auc: 0.8344
# Epoch 22/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4218 - masked_acc: 0.7589 - masked_auc: 0.8348 - val_loss: 0.4400 - val_masked_acc: 0.7597 - val_masked_auc: 0.8356
# Epoch 23/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.4259 - masked_acc: 0.7600 - masked_auc: 0.8359 - val_loss: 0.4385 - val_masked_acc: 0.7605 - val_masked_auc: 0.8366
# Epoch 24/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4196 - masked_acc: 0.7609 - masked_auc: 0.8369 - val_loss: 0.4320 - val_masked_acc: 0.7615 - val_masked_auc: 0.8376
# Epoch 25/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4216 - masked_acc: 0.7617 - masked_auc: 0.8379 - val_loss: 0.4338 - val_masked_acc: 0.7623 - val_masked_auc: 0.8386
# Epoch 26/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4226 - masked_acc: 0.7626 - masked_auc: 0.8388 - val_loss: 0.4325 - val_masked_acc: 0.7631 - val_masked_auc: 0.8395
# Epoch 27/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4176 - masked_acc: 0.7634 - masked_auc: 0.8397 - val_loss: 0.4349 - val_masked_acc: 0.7639 - val_masked_auc: 0.8403
# Epoch 28/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4155 - masked_acc: 0.7642 - masked_auc: 0.8406 - val_loss: 0.4346 - val_masked_acc: 0.7647 - val_masked_auc: 0.8411
# Epoch 29/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4103 - masked_acc: 0.7650 - masked_auc: 0.8414 - val_loss: 0.4381 - val_masked_acc: 0.7654 - val_masked_auc: 0.8420
# Epoch 30/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4105 - masked_acc: 0.7657 - masked_auc: 0.8422 - val_loss: 0.4344 - val_masked_acc: 0.7662 - val_masked_auc: 0.8428
# Epoch 31/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4083 - masked_acc: 0.7665 - masked_auc: 0.8431 - val_loss: 0.4336 - val_masked_acc: 0.7670 - val_masked_auc: 0.8437
# Epoch 32/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4083 - masked_acc: 0.7672 - masked_auc: 0.8440 - val_loss: 0.4387 - val_masked_acc: 0.7677 - val_masked_auc: 0.8445
# Epoch 33/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4006 - masked_acc: 0.7680 - masked_auc: 0.8448 - val_loss: 0.4358 - val_masked_acc: 0.7684 - val_masked_auc: 0.8452
# Epoch 34/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4085 - masked_acc: 0.7686 - masked_auc: 0.8454 - val_loss: 0.4360 - val_masked_acc: 0.7690 - val_masked_auc: 0.8459
# 23/23 [==============================] - 1s 40ms/step - loss: 0.4015 - masked_acc: 0.7693 - masked_auc: 0.8463
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4713 - masked_acc: 0.7696 - masked_auc: 0.8466
# Test:  [0.4712908864021301, 0.7695981860160828, 0.8465641140937805]
# Epoch 1/100
# 12/12 [==============================] - 9s 277ms/step - loss: 0.6305 - masked_acc: 0.5379 - masked_auc: 0.5355 - val_loss: 0.5348 - val_masked_acc: 0.6079 - val_masked_auc: 0.6436
# Epoch 2/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.5366 - masked_acc: 0.6278 - masked_auc: 0.6744 - val_loss: 0.4684 - val_masked_acc: 0.6611 - val_masked_auc: 0.7211
# Epoch 3/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4812 - masked_acc: 0.6732 - masked_auc: 0.7369 - val_loss: 0.4466 - val_masked_acc: 0.6902 - val_masked_auc: 0.7580
# Epoch 4/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4821 - masked_acc: 0.6959 - masked_auc: 0.7647 - val_loss: 0.4497 - val_masked_acc: 0.7048 - val_masked_auc: 0.7748
# Epoch 5/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4681 - masked_acc: 0.7085 - masked_auc: 0.7792 - val_loss: 0.4364 - val_masked_acc: 0.7152 - val_masked_auc: 0.7870
# Epoch 6/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4521 - masked_acc: 0.7182 - masked_auc: 0.7904 - val_loss: 0.4357 - val_masked_acc: 0.7233 - val_masked_auc: 0.7963
# Epoch 7/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4540 - masked_acc: 0.7256 - masked_auc: 0.7982 - val_loss: 0.4371 - val_masked_acc: 0.7295 - val_masked_auc: 0.8020
# Epoch 8/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4628 - masked_acc: 0.7310 - masked_auc: 0.8034 - val_loss: 0.4308 - val_masked_acc: 0.7339 - val_masked_auc: 0.8065
# Epoch 9/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4512 - masked_acc: 0.7351 - masked_auc: 0.8078 - val_loss: 0.4236 - val_masked_acc: 0.7375 - val_masked_auc: 0.8105
# Epoch 10/100
# 12/12 [==============================] - 1s 106ms/step - loss: 0.4431 - masked_acc: 0.7388 - masked_auc: 0.8118 - val_loss: 0.4253 - val_masked_acc: 0.7408 - val_masked_auc: 0.8141
# Epoch 11/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.4423 - masked_acc: 0.7418 - masked_auc: 0.8153 - val_loss: 0.4270 - val_masked_acc: 0.7435 - val_masked_auc: 0.8172
# Epoch 12/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4422 - masked_acc: 0.7443 - masked_auc: 0.8181 - val_loss: 0.4361 - val_masked_acc: 0.7456 - val_masked_auc: 0.8196
# Epoch 13/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4453 - masked_acc: 0.7462 - masked_auc: 0.8203 - val_loss: 0.4263 - val_masked_acc: 0.7474 - val_masked_auc: 0.8217
# Epoch 14/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4404 - masked_acc: 0.7480 - masked_auc: 0.8223 - val_loss: 0.4221 - val_masked_acc: 0.7492 - val_masked_auc: 0.8237
# Epoch 15/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4324 - masked_acc: 0.7498 - masked_auc: 0.8244 - val_loss: 0.4216 - val_masked_acc: 0.7508 - val_masked_auc: 0.8256
# Epoch 16/100
# 12/12 [==============================] - 1s 103ms/step - loss: 0.4372 - masked_acc: 0.7513 - masked_auc: 0.8261 - val_loss: 0.4220 - val_masked_acc: 0.7523 - val_masked_auc: 0.8273
# Epoch 17/100
# 12/12 [==============================] - 1s 100ms/step - loss: 0.4323 - masked_acc: 0.7528 - masked_auc: 0.8279 - val_loss: 0.4201 - val_masked_acc: 0.7537 - val_masked_auc: 0.8289
# Epoch 18/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4322 - masked_acc: 0.7543 - masked_auc: 0.8295 - val_loss: 0.4174 - val_masked_acc: 0.7550 - val_masked_auc: 0.8304
# Epoch 19/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4282 - masked_acc: 0.7555 - masked_auc: 0.8309 - val_loss: 0.4195 - val_masked_acc: 0.7563 - val_masked_auc: 0.8318
# Epoch 20/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4273 - masked_acc: 0.7567 - masked_auc: 0.8322 - val_loss: 0.4191 - val_masked_acc: 0.7574 - val_masked_auc: 0.8331
# Epoch 21/100
# 12/12 [==============================] - 1s 102ms/step - loss: 0.4265 - masked_acc: 0.7578 - masked_auc: 0.8335 - val_loss: 0.4221 - val_masked_acc: 0.7585 - val_masked_auc: 0.8343
# Epoch 22/100
# 12/12 [==============================] - 1s 105ms/step - loss: 0.4301 - masked_acc: 0.7588 - masked_auc: 0.8347 - val_loss: 0.4224 - val_masked_acc: 0.7594 - val_masked_auc: 0.8354
# Epoch 23/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4287 - masked_acc: 0.7598 - masked_auc: 0.8357 - val_loss: 0.4236 - val_masked_acc: 0.7602 - val_masked_auc: 0.8362
# Epoch 24/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4304 - masked_acc: 0.7605 - masked_auc: 0.8365 - val_loss: 0.4216 - val_masked_acc: 0.7610 - val_masked_auc: 0.8371
# Epoch 25/100
# 12/12 [==============================] - 1s 99ms/step - loss: 0.4256 - masked_acc: 0.7613 - masked_auc: 0.8375 - val_loss: 0.4213 - val_masked_acc: 0.7618 - val_masked_auc: 0.8380
# Epoch 26/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4343 - masked_acc: 0.7620 - masked_auc: 0.8382 - val_loss: 0.4205 - val_masked_acc: 0.7624 - val_masked_auc: 0.8387
# Epoch 27/100
# 12/12 [==============================] - 1s 101ms/step - loss: 0.4206 - masked_acc: 0.7626 - masked_auc: 0.8390 - val_loss: 0.4203 - val_masked_acc: 0.7631 - val_masked_auc: 0.8395
# Epoch 28/100
# 12/12 [==============================] - 1s 104ms/step - loss: 0.4262 - masked_acc: 0.7633 - masked_auc: 0.8397 - val_loss: 0.4190 - val_masked_acc: 0.7637 - val_masked_auc: 0.8402
# 23/23 [==============================] - 1s 39ms/step - loss: 0.4208 - masked_acc: 0.7639 - masked_auc: 0.8405
# 3/3 [==============================] - 0s 41ms/step - loss: 0.4652 - masked_acc: 0.7643 - masked_auc: 0.8408
# Test:  [0.46520423889160156, 0.764266312122345, 0.8408415913581848]

# %%
t_eval = np.array(test_eval)
print("test avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("test avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("test avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# test avg loss:  0.46889562606811525 +/- 0.005464079048305701
# test avg acc:  0.7684237957000732 +/- 0.0035556366803478692
# test avg auc:  0.8456434488296509 +/- 0.004293498523333701

# %%
t_eval = np.array(train_eval)
print("train avg loss: ", np.mean(t_eval[:, 0]), "+/-" ,np.std(t_eval[:, 0]))
print("train avg acc: ", np.mean(t_eval[:, 1]),  "+/-" ,np.std(t_eval[:, 1]))
print("train avg auc: ", np.mean(t_eval[:, 2]), "+/-" ,np.std(t_eval[:, 2]))
# Out:
# train avg loss:  0.4084496319293976 +/- 0.011361161390167048
# train avg acc:  0.7680890798568726 +/- 0.003535261829318549
# train avg auc:  0.8452823042869568 +/- 0.004249361068108503
